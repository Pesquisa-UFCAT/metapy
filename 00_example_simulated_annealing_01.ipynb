# %% [markdown]
# # Import library

# %%
# pip install metapy-toolbox or pip install --upgrade metapy-toolbox
from metapy_toolbox import simulated_annealing_01
from my_example import my_obj_function

# %% [markdown]
# # Setup

# %%
# Algorithm setup
setup = {   
            'number of iterations': 100,
            'number of population': 2,
            'number of dimensions': 2,
            'x pop lower limit': [-5, -5],
            'x pop upper limit': [5, 5],
            'none variable': None,
            'objective function': my_obj_function,
            'algorithm parameters': {
                                        'mutation': {
                                                     'cov (%)': 100,
                                                     'pdf': 'gaussian'
                                                    },
                                        'temp. control': {
                                                          'temperature t_0': 'auto',
                                                          'temperature update': 'geometric',
                                                          'alpha': 0.9
                                                         }
                                    },
        }

# Initial guess
init_pop = [[-0.74, 1.25],
            [3.58, -3.33]]
"""
or # random guess
from metapy_toolbox import initial_population_01
init_pop = initial_population_01(setup['number of population'],
                                setup['number of dimensions'],
                                setup['x pop lower limit'],
                                setup['x pop upper limit'])
"""

seed = None

# %% [markdown]
# # Call function

# %%
settings = [setup, init_pop, seed]
df_all_results, df_resume, time_cost, report = simulated_annealing_01(settings)
# Out:
# Progress: 100%|██████████| 100/100 [00:00<00:00, 1146.97it/s]

# %% [markdown]
# # Output details

# %%
df_all_results
# Out:
#               X_0           X_1            OF       FIT  ITERATION
# 0   -7.400000e-01  1.250000e+00  2.110100e+00  0.321533          0
# 1    3.580000e+00 -3.330000e+00  2.390530e+01  0.040152          0
# 2   -8.532159e-01  2.255788e+00  5.816559e+00  0.146702          1
# 3    3.497925e+00 -3.769828e+00  2.644708e+01  0.036434          1
# 4   -1.149981e+00  1.454994e+00  3.439466e+00  0.225252          2
# ..            ...           ...           ...       ...        ...
# 197  1.407467e-04 -1.961829e-12  1.980965e-08  1.000000         98
# 198  2.658729e-08 -2.048324e-03  4.195629e-06  0.999996         99
# 199 -5.448485e-05 -5.409748e-12  2.968598e-09  1.000000         99
# 200  1.375463e-08 -6.889141e-03  4.746026e-05  0.999953        100
# 201 -1.114604e-04 -3.877581e-12  1.242342e-08  1.000000        100
#
# [202 rows x 5 columns]

# %%
df_resume.tail(20)
# Out:
#      X_0_BEST      X_1_BEST       OF BEST   FIT BET  ID BEST     X_0_WORST  \
# 81   0.000040  1.353550e-03  1.833675e-06  0.999998        0  1.942523e-03
# 82   0.000054 -1.018317e-03  1.039854e-06  0.999999        0  1.456337e-03
# 83   0.000007 -7.895711e-05  6.280701e-09  1.000000        0  5.097627e-04
# 84   0.000009 -1.343740e-04  1.814381e-08  1.000000        0  1.834286e-03
# 85   0.000011 -8.326211e-05  7.043645e-09  1.000000        0  3.134687e-03
# 86   0.000023 -3.128352e-04  9.840848e-08  1.000000        0 -6.201364e-04
# 87   0.000024 -5.402895e-04  2.925073e-07  1.000000        0 -1.343717e-03
# 88   0.000025 -1.329350e-03  1.767803e-06  0.999998        0 -2.457273e-03
# 89  -0.001299 -1.692562e-11  1.687540e-06  0.999998        1  6.512341e-06
# 90   0.001069 -1.381251e-11  1.141894e-06  0.999999        1  1.247846e-06
# 91   0.000959 -2.267760e-11  9.190838e-07  0.999999        1  8.279214e-07
# 92   0.000563 -6.544270e-12  3.174961e-07  1.000000        1  2.434542e-06
# 93   0.000570 -2.015226e-11  3.249671e-07  1.000000        1 -1.623980e-06
# 94   0.000673  2.026249e-11  4.529204e-07  1.000000        1 -2.069927e-06
# 95   0.000207  1.062387e-11  4.303849e-08  1.000000        1 -6.061273e-07
# 96   0.000202 -1.486184e-12  4.091021e-08  1.000000        1 -7.280395e-07
# 97   0.000264 -2.425495e-12  6.979582e-08  1.000000        1 -6.528790e-07
# 98   0.000141 -1.961829e-12  1.980965e-08  1.000000        1 -8.985762e-07
# 99  -0.000054 -5.409748e-12  2.968598e-09  1.000000        1  2.658729e-08
# 100 -0.000111 -3.877581e-12  1.242342e-08  1.000000        1  1.375463e-08
#
#         X_1_WORST      OF WORST  FIT WORST  ID WORST        OF AVG   FIT AVG  \
# 81  -1.264491e-11  3.773397e-06   0.999996         1  2.803536e-06  0.999997
# 82   5.054837e-12  2.120918e-06   0.999998         1  1.580386e-06  0.999998
# 83   4.702322e-12  2.598580e-07   1.000000         1  1.330693e-07  1.000000
# 84   1.082040e-11  3.364605e-06   0.999997         1  1.691374e-06  0.999998
# 85   9.638480e-12  9.826262e-06   0.999990         1  4.916653e-06  0.999995
# 86   2.028438e-11  3.845692e-07   1.000000         1  2.414888e-07  1.000000
# 87   4.348816e-11  1.805574e-06   0.999998         1  1.049041e-06  0.999999
# 88   4.882917e-11  6.038192e-06   0.999994         1  3.902997e-06  0.999996
# 89  -1.359647e-03  1.848683e-06   0.999998         0  1.768111e-06  0.999998
# 90  -1.532398e-03  2.348244e-06   0.999998         0  1.745069e-06  0.999998
# 91  -1.044802e-03  1.091612e-06   0.999999         0  1.005348e-06  0.999999
# 92  -9.241508e-04  8.540607e-07   0.999999         0  5.857784e-07  0.999999
# 93  -1.811295e-03  3.280794e-06   0.999997         0  1.802880e-06  0.999998
# 94   8.049923e-04  6.480169e-07   0.999999         0  5.504686e-07  0.999999
# 95   1.485811e-03  2.207636e-06   0.999998         0  1.125337e-06  0.999999
# 96   1.275101e-03  1.625883e-06   0.999998         0  8.333968e-07  0.999999
# 97  -8.737060e-04  7.633626e-07   0.999999         0  4.165792e-07  1.000000
# 98  -9.574228e-04  9.166593e-07   0.999999         0  4.682345e-07  1.000000
# 99  -2.048324e-03  4.195629e-06   0.999996         0  2.099299e-06  0.999998
# 100 -6.889141e-03  4.746026e-05   0.999953         0  2.373634e-05  0.999976
#
#      ITERATION  neof
# 81          81   164
# 82          82   166
# 83          83   168
# 84          84   170
# 85          85   172
# 86          86   174
# 87          87   176
# 88          88   178
# 89          89   180
# 90          90   182
# 91          91   184
# 92          92   186
# 93          93   188
# 94          94   190
# 95          95   192
# 96          96   194
# 97          97   196
# 98          98   198
# 99          99   200
# 100        100   202

# %% [markdown]
# # Report

# %% [markdown]
# ### txt

# %%
filename = "report_simulated_annealing_01.txt"
with open(filename, "w") as f:
    f.write(report)

# %% [markdown]
# ### xlsx

# %%
filename = "report_simulated_annealing_01.xlsx"
df_resume.to_excel(filename, index=False)
