# %% [markdown]
# # Import library

# %%
# pip install metapy-toolbox
from metapy_toolbox import simulated_annealing_01
from my_example import my_obj_function

# %% [markdown]
# # Setup

# %%
setup = {   
            'number of iterations': 100,
            'number of population': 2,
            'number of dimensions': 2,
            'x pop lower limit': [-5, -5],
            'x pop upper limit': [5, 5],
            'none variable': None,
            'objective function': my_obj_function,
            'algorithm parameters': {'cov (%)': 20,
                                     'pdf': 'gaussian',
                                     'temperature': 15,
                                     'temperature update': 'geometric',
                                     'alpha': 0.9}
        }

# Initial guess
init_pop = [[-0.74, 1.25],
            [3.58, -3.33]]
"""
or # random guess
from metapy_toolbox import initial_population_01
init_pop = initial_population_01(setup['number of population'],
                                setup['number of dimensions'],
                                setup['x pop lower limit'],
                                setup['x pop upper limit'])
"""

seed = None

# %% [markdown]
# # Call function

# %%
settings = [setup, init_pop, seed]
df_all_results, df_resume, time_cost, report = simulated_annealing_01(settings)

# %% [markdown]
# # Output details

# %%
df_all_results
# Out:
#           X_0       X_1         OF       FIT  ITERATION
# 0   -0.740000  1.250000   2.110100  0.321533          0
# 1    3.580000 -3.330000  23.905300  0.040152          0
# 2   -1.035174  1.544785   3.457948  0.224318          1
# 3    3.944717 -3.775650  29.816325  0.032450          1
# 4   -0.955978  1.079301   2.078784  0.324804          2
# ..        ...       ...        ...       ...        ...
# 197  0.049132 -0.046383   0.004565  0.995455         98
# 198 -0.031466  0.029887   0.001883  0.998120         99
# 199  0.052945 -0.031465   0.003793  0.996221         99
# 200 -0.026365  0.022788   0.001214  0.998787        100
# 201  0.049754 -0.027305   0.003221  0.996789        100
#
# [202 rows x 5 columns]

# %%
df_resume.tail(20)
# Out:
#           X_0       X_1   OF BEST   FIT BET  ID BEST       X_0       X_1  \
# 81  -0.052457  0.027455  0.003506  0.996507        0  0.126299 -0.130548
# 82  -0.054691  0.024069  0.003570  0.996442        0  0.126299 -0.130548
# 83  -0.054691  0.024069  0.003570  0.996442        0  0.116948 -0.130893
# 84  -0.048499  0.018537  0.002696  0.997311        0  0.116948 -0.130893
# 85  -0.054775  0.019453  0.003379  0.996633        0  0.109025 -0.116539
# 86  -0.048790  0.027057  0.003113  0.996897        0  0.096806 -0.129025
# 87  -0.045992  0.029982  0.003014  0.996995        0  0.096806 -0.129025
# 88  -0.047251  0.022669  0.002747  0.997261        0  0.096806 -0.129025
# 89  -0.047251  0.022669  0.002747  0.997261        0  0.084500 -0.105963
# 90  -0.047251  0.022669  0.002747  0.997261        0  0.071359 -0.069992
# 91  -0.042531  0.021122  0.002255  0.997750        0  0.051957 -0.068276
# 92  -0.042489  0.015579  0.002048  0.997956        0  0.044246 -0.088652
# 93  -0.042489  0.015579  0.002048  0.997956        0  0.036450 -0.088013
# 94  -0.042489  0.015579  0.002048  0.997956        0  0.037467 -0.074408
# 95  -0.042489  0.015579  0.002048  0.997956        0  0.039263 -0.068555
# 96  -0.039387  0.022030  0.002037  0.997967        0  0.039355 -0.058960
# 97  -0.032428  0.024152  0.001635  0.998368        0  0.039355 -0.058960
# 98  -0.030491  0.022724  0.001446  0.998556        0  0.049132 -0.046383
# 99  -0.031466  0.029887  0.001883  0.998120        0  0.052945 -0.031465
# 100 -0.026365  0.022788  0.001214  0.998787        0  0.049754 -0.027305
#
#      OF WORST  FIT WORST  ID WORST    OF AVG   FIT AVG  ITERATION  neof
# 81   0.032994   0.968060         1  0.018250  0.982283         81   164
# 82   0.032994   0.968060         1  0.018282  0.982251         82   166
# 83   0.030810   0.970111         1  0.017190  0.983277         83   168
# 84   0.030810   0.970111         1  0.016753  0.983711         84   170
# 85   0.025468   0.975165         1  0.014423  0.985899         85   172
# 86   0.026019   0.974641         1  0.014566  0.985769         86   174
# 87   0.026019   0.974641         1  0.014516  0.985818         87   176
# 88   0.026019   0.974641         1  0.014383  0.985951         88   178
# 89   0.018368   0.981963         1  0.010557  0.989612         89   180
# 90   0.009991   0.990108         1  0.006369  0.993684         90   182
# 91   0.007361   0.992693         1  0.004808  0.995221         91   184
# 92   0.009817   0.990279         1  0.005932  0.994117         92   186
# 93   0.009075   0.991007         1  0.005561  0.994481         93   188
# 94   0.006940   0.993108         1  0.004494  0.995532         94   190
# 95   0.006241   0.993797         1  0.004145  0.995877         95   192
# 96   0.005025   0.995000         1  0.003531  0.996484         96   194
# 97   0.005025   0.995000         1  0.003330  0.996684         97   196
# 98   0.004565   0.995455         1  0.003006  0.997006         98   198
# 99   0.003793   0.996221         1  0.002838  0.997171         99   200
# 100  0.003221   0.996789         1  0.002218  0.997788        100   202

# %% [markdown]
# # Report

# %% [markdown]
# ### txt

# %%
filename = "report_simulated_annealing_01.txt"
with open(filename, "w") as f:
    f.write(report)

# %% [markdown]
# ### xlsx

# %%
filename = "report_simulated_annealing_01.xlsx"
df_resume.to_excel(filename, index=False)
