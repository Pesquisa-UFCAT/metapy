# %%
# import numpy as np
# from multiprocessing import Pool
# import time
# import pandas as pd
# import sys
from OF_FUNCTION import *
from META_TOOLBOX import *
from EASYPLOT_TOOLBOX import *

# %%
SETUP = {
            'ALGORITHM': 'GRADIENT 01',
            'N_REP': 10,
            'N_POP': 1,
            'N_ITER': 4,
            'X_L': [-5, -5],
            'X_U': [5, 5],
            'D': 2,
            'PARAMETERS': {'DIRECTION_SEARCH': 'BFGS'},
            'NULL_DIC': None,
            'OF': MY_FUNCTION,
            'FIRST ORDER DERIVATIVE': MY_FUNCTION_DERIVATIVE
        }

RESULTS_REP, BEST_REP, AVERAGE_REP, WORST_REP, STATUS_PROCEDURE = META(SETUP)
# Out:
#  Optimization results:
#
#  - Design Variables:  [-0.3333333333333349, -0.499999999999999]
#
#  - Of value:         -3.333333e-01
#
#  - Process time (s): 4.643997

# %%
BEST_REP[STATUS_PROCEDURE[0]]
# Out:
# {'X_POSITION': array([[-4.56342294,  2.65621698],
#         [ 0.01891529,  0.15754154],
#         [-0.33333333, -0.5       ],
#         [-0.33333333, -0.5       ],
#         [-0.33333333, -0.5       ]]),
#  'OF': array([ 4.14450354e+02,  1.05642066e-01, -3.33333333e-01, -3.33333333e-01,
#         -3.33333333e-01]),
#  'FIT': array([0.00240703, 0.90445184, 1.33333333, 1.33333333, 1.33333333]),
#  'NEOF': array([1., 2., 3., 4., 5.]),
#  'ID_PARTICLE': array([0., 0., 0., 0., 0.]),
#  'PARAMETERS': [{'ITER': 0,
#    'TIME (s)': 0.0,
#    'X_(K)': array([[-4.56342294,  2.65621698]]),
#    'X_(K-1)': 0,
#    'BETA': None,
#    'S(K-1)': [0, 0],
#    'ERROR': 1000},
#   {'ITER': 1,
#    'TIME (s)': 0.0009963512420654297,
#    'X_(K)': array([[-4.56342294,  2.65621698]]),
#    'X_(K-1)': 0,
#    'BETA': None,
#    'S(K-1)': [0, 0],
#    'ALPHA': 0.032872632190799625,
#    'ERROR': 3922.156474264191},
#   {'ITER': 2,
#    'TIME (s)': 0.0,
#    'X_(K)': array([[0.01891529, 0.15754154]]),
#    'X_(K-1)': array([[-4.56342294,  2.65621698]]),
#    'BETA': None,
#    'S(K-1)': array([[1., 0.],
#           [0., 1.]]),
#    'ALPHA': 0.6337592077328056,
#    'ERROR': 1.3169261974257345},
#   {'ITER': 3,
#    'TIME (s)': 0.0,
#    'X_(K)': array([[-0.33333333, -0.5       ]]),
#    'X_(K-1)': array([[0.01891529, 0.15754154]]),
#    'BETA': None,
#    'S(K-1)': array([[0.24833823, 0.40245608],
#           [0.40245608, 0.78458935]]),
#    'ALPHA': 0.5066397717851502,
#    'ERROR': 1.665334536937734e-15},
#   {'ITER': 4,
#    'TIME (s)': 0.0,
#    'X_(K)': array([[-0.33333333, -0.5       ]]),
#    'X_(K-1)': array([[-0.33333333, -0.5       ]]),
#    'BETA': None,
#    'S(K-1)': array([[0.16666667, 0.25      ],
#           [0.25      , 0.5       ]]),
#    'ALPHA': 0.8522018253798994,
#    'ERROR': 6.661338147750932e-16}]}

# %%
# Data
LEGEND = ['Best rep.', 'Worst rep.']
LINE_STY = ['-', '-']
OF_VALUES = [
            list(BEST_REP[STATUS_PROCEDURE[0]]['OF']),
            list(BEST_REP[STATUS_PROCEDURE[-1]]['OF'])
         ]
EVALUATIONS = list(BEST_REP[STATUS_PROCEDURE[0]]['NEOF'])
COLORS = ['blue','green']

# Chart setup
CHART_CONFIG = {
              'NAME': 'figure5',
              'WIDTH': 0.20, 
              'HEIGHT': 0.10,
              'MARKER': None,
              'MARKER SIZE': 3,
              'LINE WIDTH': 4,
              'LINE STYLE': LINE_STY,
              'X AXIS LABEL': 'Function evaluations ($NEOF$)',
              'X AXIS SIZE': 14,
              'Y AXIS LABEL': '$OF$ value',
              'Y AXIS SIZE': 14,
              'AXISES COLOR': '#000000',
              'LABELS SIZE': 14,
              'LABELS COLOR': '#000000',
              'CHART COLOR': COLORS,
              'ON GRID?': True,
              'LOC LEGEND': 'upper right',
              'SIZE LEGEND': 14,
              'Y LOG': False,
              'X LOG': False,
              'DPI': 600, 
              'EXTENSION': 'svg'
             }

# Data statement 
DATA = {'X': EVALUATIONS, 'Y': OF_VALUES, 'LEGEND': LEGEND}

# Call function
LINE_CHART(DATASET = DATA, PLOT_SETUP = CHART_CONFIG)
