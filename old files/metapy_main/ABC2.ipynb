# %%
import numpy as np
import random
import math

# %%
def f(x):
  m = []
  for j in range(len(x)):
    m.append(x[j][0]**2 + x[j][1]**2)
  return m

def fit(y):
  n =[]
  for i in range(len(y)):
    if(y[i]>=0):
      n.append(1/(1+y[i]))
    if(y[i]<0):
      n.append(1+abs(y[i]))
  return n

#PARÂMETROS
LL = -5         #Limite inferior
UL = 5          #Limite superior
CS = 6          #Tamanho da colônia
D = 2           #Dimensões
L = (CS*D)/2

'''
X = []
for j in range(int(CS/2)):
  n = []
  for i in range(2):
    n.append(random.uniform(LL, UL))
  X.append(n)
'''
#testeeeeeeeeeeeeeeeeeee
X = [[1.4112, -2.5644],
     [0.4756, 1.4338],
     [-0.1824, -1.0323]]

sol = [0]*int(CS/2)

#testeeeeeeeeeeeeeeeeeeeeeeeeee
phi = [0.8050, 0.0762, -0.0671]
k0 = [1, 2, 0]
j0 = [0, 1, 0]


V = X
for i in range(len(X)):
  #phi = random.uniform(-1, 1)
  #j = random.randint(0, len(X[0])-1)
  #k = random.randint(0, len(X)-1)
  k = k0[i]
  j = j0[i]
  V[i][j] = X[i][j] + phi[i]*(X[i][j]-X[k][j])

print("X:", X)
print("V:", V)
# Out:
# X: [[2.164358, -2.5644], [0.4756, 1.62171682], [-0.024932538199999993, -1.0323]]
# V: [[2.164358, -2.5644], [0.4756, 1.62171682], [-0.024932538199999993, -1.0323]]

# %%
def f(x):
  m = []
  for j in range(len(x)):
    m.append(x[j][0]**2 + x[j][1]**2)
  return m

def fit(y):
  n =[]
  for i in range(len(y)):
    if(y[i]>=0):
      n.append(1/(1+y[i]))
    if(y[i]<0):
      n.append(1+abs(y[i]))
  return n


#PARÂMETROS
LL = -5         #Limite inferior
UL = 5          #Limite superior
CS = 6          #Tamanho da colônia
D = 2           #Dimensões
L = (CS*D)/2

X = []

for j in range(int(CS/2)):
  n = []
  for i in range(2):
    n.append(random.uniform(LL, UL))
  X.append(n)

#testeeeeeeeeeeeeeeeeeee
X = [[1.4112, -2.5644],
     [0.4756, 1.4338],
     [-0.1824, -1.0323]]

FITX = fit(f(X))
FIT_BEST = max(FITX)

sol = [0]*int(CS/2)

#testeeeeeeeeeeeeeeeeeeeeeeeeee
phi = [0.8050, 0.0762, -0.0671]
k0 = [1, 2, 0]
j0 = [0, 1, 0]

V = X
for i in range(len(X)):
  #phi = random.uniform(-1, 1)
  #j = random.randint(0, len(X[0])-1)
  #k = random.randint(0, len(X)-1)
  k = k0[i]
  j = j0[i]
  V[i][j] = X[i][j] + phi[i]*(X[i][j]-X[k][j])
FITV = fit(f(V))

for c in range(len(FITV)):
  if(FITV[c]<FITX[c]):
    sol[c] = sol[c] + 1
  else:
    X[c] = V[c]
    sol[c] = 0


print("X   :", X)
print("f(X):", f(X))
#print("V   :", V)
#print("f(V):", f(V))
#print("FITV:", FITV)
#print("sol :", sol)


p = []
for i in range(int(CS/2)):
  n = FITX[i]/(sum(FITX))
  p.append(n)

print(p)
# Out:
# X   : [[2.164358, -2.5644], [0.4756, 1.62171682], [-0.024932538199999993, -1.0323]]
# f(X): [11.260592912164, 2.8561608042709126, 1.0662649214610944]
# [0.11801389599925705, 0.344034509379765, 0.537951594620978]

# %% [markdown]
# # Employed Bees phase

# %% [markdown]
# # Onlooker bees phase

# %%
for i in range():
