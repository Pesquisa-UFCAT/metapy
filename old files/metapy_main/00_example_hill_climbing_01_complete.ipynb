# %% [markdown]
# # Import library

# %%
# pip install metapy-toolbox or pip install --upgrade metapy-toolbox
from my_example import my_obj_function
from metapy_toolbox import metaheuristic_optimizer

# %% [markdown]
# # Setup and call function

# %%
param_grid = {  
        'cov (%)': [5, 8, 10, 15, 20],
        'pdf': ['gaussian', 'uniform'],
        'number of iterations': [100, 200, 300],
        'number of population': [2, 3, 4],
}

algorithm_setup = {   
    'number of iterations': 'parametrizer',
    'number of population': 'parametrizer',
    'number of dimensions': 2,
    'x pop lower limit': [-5, -5],
    'x pop upper limit': [5, 5],
    'none variable': None,
    'objective function': 'my_obj_function',
    'objective function': my_obj_function,
    'algorithm parameters': {
            'mutation': {
                'cov (%)': 'parametrizer',
                'pdf': 'parametrizer'
            }
    }
}

from sklearn.model_selection import ParameterGrid
from copy import deepcopy

def parametrizer_grid(param_grid, algorithm_setup):
    # Generate all possible combinations of parameters
    param_combinations = list(ParameterGrid(param_grid))
    algorithm_setups_with_params = []
    
    for params in param_combinations:
        setup_copy = deepcopy(algorithm_setup)
        
        # Function to replace 'parametrizer' by the actual value
        def replace_parametrizer(obj, params):
            if isinstance(obj, dict):
                for k, v in obj.items():
                    if v == 'parametrizer' and k in params:
                        obj[k] = params[k] # Replace 'parametrizer' by the actual value
                    elif isinstance(v, (dict, list)):
                        replace_parametrizer(v, params)
            elif isinstance(obj, list):
                for i, item in enumerate(obj):
                    if item == 'parametrizer' and i in params:
                        obj[i] = params[i]
                    elif isinstance(item, (dict, list)):
                        replace_parametrizer(item, params)

        replace_parametrizer(setup_copy, params)
        
        # Add the setup to the list
        if setup_copy not in algorithm_setups_with_params:
            algorithm_setups_with_params.append(setup_copy)
    
    return algorithm_setups_with_params

# Exemplo de uso
results = parametrizer_grid(param_grid, algorithm_setup)
for i, setup in enumerate(results):
    print(f"Configuração {i+1}: {setup}\n")
# Out:
# Configuração 1: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 2: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 3: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 4: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 5: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 6: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 7: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 8: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 9: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 10: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 11: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 12: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 13: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 14: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 15: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 16: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 17: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'gaussian'}}}
#
# Configuração 18: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 5, 'pdf': 'uniform'}}}
#
# Configuração 19: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 20: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 21: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 22: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 23: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 24: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 25: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 26: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 27: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 28: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 29: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 30: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 31: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 32: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 33: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 34: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 35: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'gaussian'}}}
#
# Configuração 36: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 8, 'pdf': 'uniform'}}}
#
# Configuração 37: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 38: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 39: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 40: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 41: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 42: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 43: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 44: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 45: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 46: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 47: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 48: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 49: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 50: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 51: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 52: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 53: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'gaussian'}}}
#
# Configuração 54: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 10, 'pdf': 'uniform'}}}
#
# Configuração 55: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 56: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 57: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 58: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 59: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 60: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 61: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 62: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 63: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 64: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 65: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 66: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 67: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 68: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 69: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 70: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 71: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'gaussian'}}}
#
# Configuração 72: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 15, 'pdf': 'uniform'}}}
#
# Configuração 73: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 74: {'number of iterations': 100, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 75: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 76: {'number of iterations': 100, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 77: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 78: {'number of iterations': 100, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 79: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 80: {'number of iterations': 200, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 81: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 82: {'number of iterations': 200, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 83: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 84: {'number of iterations': 200, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 85: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 86: {'number of iterations': 300, 'number of population': 2, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 87: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 88: {'number of iterations': 300, 'number of population': 3, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}
#
# Configuração 89: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}}
#
# Configuração 90: {'number of iterations': 300, 'number of population': 4, 'number of dimensions': 2, 'x pop lower limit': [-5, -5], 'x pop upper limit': [5, 5], 'none variable': None, 'objective function': <function my_obj_function at 0x0000026D1E2AAD40>, 'algorithm parameters': {'mutation': {'cov (%)': 20, 'pdf': 'uniform'}}}

# %%
param_grid = {  
        'cov (%)': [5, 8, 10, 15, 20],
        'pdf': ['gaussian', 'uniform'],
        'number of iterations': [100],
        'number of population': [2],
}

algorithm_setup = {   
    'number of iterations': 'parametrizer',
    'number of population': 'parametrizer',
    'number of dimensions': 2,
    'x pop lower limit': [-5, -5],
    'x pop upper limit': [5, 5],
    'none variable': None,
    'objective function': 'my_obj_function',
    'objective function': my_obj_function,
    'algorithm parameters': {
            'mutation': {
                'cov (%)': 'parametrizer',
                'pdf': 'parametrizer'
            }
    }
}

# METApy settings
general_setup = {   
        'number of repetitions': 30,
        'type code': 'real code',
        'initial pop. seed': [None] * 30,
        'algorithm': 'hill_climbing_01',
        }


def grid_params_metaheuristic(param_grid, algorithm_setup, general_setup):
        results = []
        # Generate all possible combinations of parameters
        param_combinations = parametrizer_grid(param_grid, algorithm_setup)
        for params in param_combinations:
                _, df_resume_all_reps, _, status = metaheuristic_optimizer(params, general_setup)
                # Save results
                results.append({
                'params': params,
                'OF BEST': df_resume_all_reps[status].iloc[-1]['OF BEST']
        })
        results = pd.DataFrame(results)
        best_parameter = results.loc[results['OF BEST'].idxmin()]

        return results, best_parameter
        
results, best_parameter = grid_params_metaheuristic(param_grid, algorithm_setup, general_setup)
# Out:
#  Optimization results:
#
#  - Best repetition id:    27
#  - Best of:               1.3913892586e-02
#  - Design variables:      [0.09357259525564768, 0.07181964914477566]
#  - Process time (s):      2.576564
#  - Best process time (s): 0.001085
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               1.1291099988e-01
#  - Design variables:      [0.05307547657568284, 0.3318041495628405]
#  - Process time (s):      2.482978
#  - Best process time (s): 0.001000
#
#  Optimization results:
#
#  - Best repetition id:    25
#  - Best of:               3.5692626612e-04
#  - Design variables:      [0.011694617879822228, -0.014837863011954208]
#  - Process time (s):      2.594412
#  - Best process time (s): 0.001076
#
#  Optimization results:
#
#  - Best repetition id:    23
#  - Best of:               1.7145873656e-03
#  - Design variables:      [0.03076213761088782, 0.027717832802080386]
#  - Process time (s):      2.638776
#  - Best process time (s): 0.001008
#
#  Optimization results:
#
#  - Best repetition id:    12
#  - Best of:               4.7520176726e-04
#  - Design variables:      [0.015530847231326647, 0.015296880451277148]
#  - Process time (s):      2.416090
#  - Best process time (s): 0.001000
#
#  Optimization results:
#
#  - Best repetition id:    13
#  - Best of:               2.6640690985e-03
#  - Design variables:      [-0.011984938602271601, -0.05020388775016277]
#  - Process time (s):      2.569174
#  - Best process time (s): 0.001000
#
#  Optimization results:
#
#  - Best repetition id:    4
#  - Best of:               3.9992956137e-06
#  - Design variables:      [0.001273549980472746, 0.0015418709611676185]
#  - Process time (s):      2.421415
#  - Best process time (s): 0.001015
#
#  Optimization results:
#
#  - Best repetition id:    21
#  - Best of:               2.8043111397e-03
#  - Design variables:      [-0.029499330767857827, 0.04397841088510893]
#  - Process time (s):      3.201395
#  - Best process time (s): 0.001000
#
#  Optimization results:
#
#  - Best repetition id:    27
#  - Best of:               1.0358675421e-09
#  - Design variables:      [2.6712134718596702e-05, 1.7953534495701573e-05]
#  - Process time (s):      3.101901
#  - Best process time (s): 0.000999
#
#  Optimization results:
#
#  - Best repetition id:    22
#  - Best of:               1.7705275954e-04
#  - Design variables:      [-0.010520159313866734, 0.00814733131467079]
#  - Process time (s):      2.744224
#  - Best process time (s): 0.001010

# %%
results
# Out:
#                                               params       OF BEST
# 0  {'number of iterations': 100, 'number of popul...  1.391389e-02
# 1  {'number of iterations': 100, 'number of popul...  1.129110e-01
# 2  {'number of iterations': 100, 'number of popul...  3.569263e-04
# 3  {'number of iterations': 100, 'number of popul...  1.714587e-03
# 4  {'number of iterations': 100, 'number of popul...  4.752018e-04
# 5  {'number of iterations': 100, 'number of popul...  2.664069e-03
# 6  {'number of iterations': 100, 'number of popul...  3.999296e-06
# 7  {'number of iterations': 100, 'number of popul...  2.804311e-03
# 8  {'number of iterations': 100, 'number of popul...  1.035868e-09
# 9  {'number of iterations': 100, 'number of popul...  1.770528e-04

# %%
print("---"*25)
print(f"BEST ALGORITHM PARAMETERS:")
print("---"*25)
for k, v in best_parameter['params'].items():
    print(f"{k}: {v}")
# Out:
# ---------------------------------------------------------------------------
# BEST ALGORITHM PARAMETERS:
# ---------------------------------------------------------------------------
# number of iterations: 100
# number of population: 2
# number of dimensions: 2
# x pop lower limit: [-5, -5]
# x pop upper limit: [5, 5]
# none variable: None
# objective function: <function my_obj_function at 0x0000026D1E2AAD40>
# algorithm parameters: {'mutation': {'cov (%)': 20, 'pdf': 'gaussian'}}

# %%
results = []
for params in grid:
        # Algorithm settings
        algorithm_setup = {   
                        'number of iterations': 100,
                        'number of population': 2,
                        'number of dimensions': 2,
                        'x pop lower limit': [-5, -5],
                        'x pop upper limit': [5, 5],
                        'none variable': None,
                        'objective function': my_obj_function,
                        'algorithm parameters': {
                                'mutation': params,
                        }
                        }

        # METApy settings
        general_setup = {   
                'number of repetitions': 30,
                'type code': 'real code',
                'initial pop. seed': [None] * 30,
                'algorithm': 'hill_climbing_01',
                }

        # Run algorithm
        df_all_reps, df_resume_all_reps, reports, status = metaheuristic_optimizer(algorithm_setup, general_setup)

        # Save results
        results.append({
        'params': params,
        'OF BEST': df_resume_all_reps[status].iloc[-1]['OF BEST']
    })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 results = []
# ----> 2 for params in grid:
#       3         # Algorithm settings
#       4         algorithm_setup = {
#       5                         'number of iterations': 100,
#       6                         'number of population': 2,
#    (...)
#      14                         }
#      15                         }
#      17         # METApy settings
#
# NameError: name 'grid' is not defined

# %% [markdown]
# # Best results

# %%
results = pd.DataFrame(results)
results
# Out:
#                                params       OF BEST
# 0   {'cov (%)': 5, 'pdf': 'gaussian'}  9.807578e-03
# 1    {'cov (%)': 5, 'pdf': 'uniform'}  4.969986e-03
# 2   {'cov (%)': 8, 'pdf': 'gaussian'}  3.470252e-03
# 3    {'cov (%)': 8, 'pdf': 'uniform'}  8.868805e-04
# 4  {'cov (%)': 10, 'pdf': 'gaussian'}  1.196548e-03
# 5   {'cov (%)': 10, 'pdf': 'uniform'}  8.495285e-03
# 6  {'cov (%)': 15, 'pdf': 'gaussian'}  1.318717e-06
# 7   {'cov (%)': 15, 'pdf': 'uniform'}  3.832360e-04
# 8  {'cov (%)': 20, 'pdf': 'gaussian'}  1.245418e-07
# 9   {'cov (%)': 20, 'pdf': 'uniform'}  6.691386e-05

# %%
df_resume_all_reps[status]
# Out:
#      X_0_BEST  X_1_BEST   OF BEST   FIT BET  ID BEST  X_0_WORST  X_1_WORST  \
# 0    0.352705 -0.160002  0.150002  0.869564        1  -4.505738   2.688192
# 1    0.285999 -0.131505  0.099089  0.909844        1  -3.782089   2.973230
# 2    0.285999 -0.131505  0.099089  0.909844        1  -3.323979   3.142953
# 3    0.246537 -0.133511  0.078605  0.927123        1  -3.323979   3.142953
# 4    0.246537 -0.133511  0.078605  0.927123        1  -3.323979   3.142953
# ..        ...       ...       ...       ...      ...        ...        ...
# 96   0.005861 -0.008235  0.000102  0.999898        1  -0.084940   0.084767
# 97   0.005861 -0.008235  0.000102  0.999898        1  -0.076238   0.071540
# 98   0.006118 -0.007495  0.000094  0.999906        1  -0.064869   0.081038
# 99   0.007052 -0.006497  0.000092  0.999908        1  -0.063882   0.068568
# 100  0.005654 -0.005912  0.000067  0.999933        1  -0.063882   0.068568
#
#       OF WORST  FIT WORST  ID WORST     OF AVG   FIT AVG  ITERATION  neof
# 0    27.528055   0.035053         0  13.839028  0.452309          0     2
# 1    23.144297   0.041418         0  11.621693  0.475631          1     4
# 2    20.926989   0.045606         0  10.513039  0.477725          2     6
# 3    20.926989   0.045606         0  10.502797  0.486364          3     8
# 4    20.926989   0.045606         0  10.502797  0.486364          4    10
# ..         ...        ...       ...        ...       ...        ...   ...
# 96    0.014400   0.985804         0   0.007251  0.992851         96   194
# 97    0.010930   0.989188         0   0.005516  0.994543         97   196
# 98    0.010775   0.989340         0   0.005434  0.994623         98   198
# 99    0.008782   0.991294         0   0.004437  0.995601         99   200
# 100   0.008782   0.991294         0   0.004425  0.995614        100   202
#
# [101 rows x 14 columns]
