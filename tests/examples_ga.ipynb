# %% [markdown]
# # Libraries

# %%
import sys
my_framework_path = '/home/wmpjrufg/Documents/metapy' # PC prof. wanderlei at umn
my_framework_path = r'C:\git-projetos\metapy' # PC prof. wanderlei
sys.path.append(my_framework_path)
from metapy_toolbox import *

# %% [markdown]
# # GA tests

# %%
x_ini = [[0.5, 3, 1], [1.5, 8.0, 1], [2.5, 2.5, 1], [3.5, 3.5, 1]]
paras = {'selection': 'roulette wheel',
          'crossover': {'type': 'linear', 'crossover rate (%)': 80},
          'mutation': {'type': 'none', 'mutation rate (%)': 10}}
n_gen = 5
frame, best = genetic_algorithm_01(sphere, n_gen, paras, x_ini, [0]*3, [5]*3)
best
# Out:
#    ID  ITER  X_0  X_1  X_2     OF       FIT  OF EVALUATIONS  \
# 0   0     1  0.5  3.0    1  10.25  0.088889               6
#
#    TIME CONSUMPTION (s) REPORT  P_X_BEST_0  P_X_BEST_1  P_X_BEST_2  P_OF_BEST
# 0              0.000022                0.5         3.0           1      10.25
#    ID  ITER  X_0  X_1  X_2    OF       FIT  OF EVALUATIONS  \
# 0   1     1  0.0  0.5  1.0  1.25  0.444444               9
#
#    TIME CONSUMPTION (s)
# 0              0.000015
#    ID  ITER  X_0  X_1  X_2   OF  FIT  OF EVALUATIONS  TIME CONSUMPTION (s)
# 0   2     1  2.0  2.0  1.0  9.0  0.1              12              0.000018
#    ID  ITER  X_0  X_1  X_2   OF  FIT  OF EVALUATIONS  TIME CONSUMPTION (s)
# 0   3     1  2.0  2.0  1.0  9.0  0.1              15              0.000022
#    ID  ITER  X_0  X_1  X_2   OF  FIT  OF EVALUATIONS  TIME CONSUMPTION (s)
# 0   0     2  0.0  0.0  1.0  1.0  0.5              18              0.000038
#    ID  ITER  X_0  X_1  X_2    OF       FIT  OF EVALUATIONS  \
# ...

# %%
frame
# Out:
#     ID  ITER  X_0  X_1  X_2     OF       FIT  OF EVALUATIONS  \
# 0    0     0  0.5  3.0  1.0  10.25  0.088889               0
# 1    1     0  1.5  8.0  1.0  67.25  0.014652               1
# 2    2     0  2.5  2.5  1.0  13.50  0.068966               2
# 3    3     0  3.5  3.5  1.0  25.50  0.037736               3
# 4    0     1  0.5  3.0  1.0  10.25  0.088889               6
# 5    1     1  0.0  0.5  1.0   1.25  0.444444               9
# 6    2     1  2.0  2.0  1.0   9.00  0.100000              12
# 7    3     1  2.0  2.0  1.0   9.00  0.100000              15
# 8    0     2  0.0  0.0  1.0   1.00  0.500000              18
# 9    1     2  0.0  0.5  1.0   1.25  0.444444              18
# 10   2     2  0.0  0.0  1.0   1.00  0.500000              21
# 11   3     2  0.0  0.0  1.0   1.00  0.500000              24
# 12   0     3  0.0  0.0  1.0   1.00  0.500000              27
# 13   1     3  0.0  0.0  1.0   1.00  0.500000              30
# ...

# %%
ultimo_report = frame['REPORT'].iloc[-1]
print(ultimo_report)
# Out:
# Genetic Algorithm
# iteration: 1
#  Agent id: 0
#     Selection operator
#     sum(fit) = 0.12135338094999773
#     probs(fit) = [0.0, 0.12073841319717205, 0.5683032207384132, 0.3109583660644148]
#     selected agent id = 2
#     Crossover operator - Linear crossover
#     current p0 = [np.float64(0.5), np.float64(3.0), np.int64(1)]
#     current p1 = [np.float64(2.5), np.float64(2.5), np.int64(1)]
#     Dimension 0: alpha_a = 0.25, beta_a = 1.25, neighbor_a = 1.5
#     Dimension 0: alpha_b = 0.75, beta_b = 1.25, neighbor_b = -0.5
#     Dimension 0: alpha_c = 0.25, beta_c = 3.75, neighbor_c = 3.5
#     Dimension 1: alpha_a = 1.5, beta_a = 1.25, neighbor_a = 2.75
#     Dimension 1: alpha_b = 4.5, beta_b = 1.25, neighbor_b = 3.25
#     Dimension 1: alpha_c = 1.5, beta_c = 3.75, neighbor_c = 2.25
#     Dimension 2: alpha_a = 0.5, beta_a = 0.5, neighbor_a = 1.0
#     Dimension 2: alpha_b = 1.5, beta_b = 0.5, neighbor_b = 1.0
# ...
