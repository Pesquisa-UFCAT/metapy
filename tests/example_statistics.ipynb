# %%
import sys
my_framework_path = '/home/wmpjrufg/Documents/metapy' # PC prof. wanderlei at umn
my_framework_path = r'C:\git-projetos\metapy' # PC prof. wanderlei
sys.path.append(my_framework_path)
from metapy_toolbox import *

# %%
yA = [10.3657, 8.7520, 10.9005, 11.2341, 9.5612, 9.8427, 11.0183, 9.2796, 10.1564, 10.9478,
      10.2219, 8.9355, 9.7743, 11.5632, 10.4385, 9.9867, 10.7421, 11.1274, 9.3148, 10.5839,
      8.9812, 9.6547, 10.3188, 11.0425, 10.7056, 9.4271, 9.9914, 10.6388, 10.4953, 10.5170]

yB = [13.9983, 10.4310, 10.2829, 9.9847, 12.1765, 10.9154, 11.6392, 11.3826, 12.4471, 9.9986,
      10.5525, 10.3415, 10.1056, 10.6148, 13.0929, 9.7878, 12.3556, 11.7483, 10.9832, 12.2647,
      11.5021, 9.9539, 11.1284, 12.0167, 10.7429, 11.6317, 12.4825, 10.8691, 11.4103, 12.1086]

p_better, p_worse, p_equal = statistics.pair_wise(yA, yB, "max")
print(f"yA better: {p_better}, yB better: {p_worse}, equal: {p_equal}")
# Out:
# yA better: 0.21444444444444444, yB better: 0.7855555555555556, equal: 0.0
